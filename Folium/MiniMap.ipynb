# %%
import folium
from folium import plugins

big_map = folium.Map(location=(20, 78), zoom_start=13)
mini_map = plugins.MiniMap(toggle_display=True)

big_map.add_child(mini_map)
big_map
# Out:
# <PIL.Image.Image image mode=RGB size=1157x693 at 0x7FCDB76D2DD0>
